# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\situ\Desktop\EDA project\diamonds.csv")
df
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %%
df.drop(columns='Unnamed: 0',inplace=True)

# %%
df.sample()
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 35773    0.4  Premium     E     VS2   62.2   59.0    912  4.71  4.74  2.94

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
df.isnull().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 146

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %% [markdown]
# # choose your target column & store in 'y' and remain columns are x

# %%
y=df['table']
x=df.drop(columns='table')

# %%
x
# Out:
#        carat        cut color clarity  depth  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   2757  5.83  5.87  3.64
#
# [53794 rows x 9 columns]

# %%
import sklearn
from sklearn.model_selection import train_test_split

# %% [markdown]
# # from 'x' columns separate catagorical & contineous and create indivisual data frame

# %%
x_contineous = x[['carat', 'depth', 'price', 'x', 'y', 'z']]
x_catagorical = x[['cut', 'color', 'clarity']]

# %%
x_contineous
# Out:
#        carat  depth  price     x     y     z
# 0       0.23   61.5    326  3.95  3.98  2.43
# 1       0.21   59.8    326  3.89  3.84  2.31
# 2       0.23   56.9    327  4.05  4.07  2.31
# 3       0.29   62.4    334  4.20  4.23  2.63
# 4       0.31   63.3    335  4.34  4.35  2.75
# ...      ...    ...    ...   ...   ...   ...
# 53935   0.72   60.8   2757  5.75  5.76  3.50
# 53936   0.72   63.1   2757  5.69  5.75  3.61
# 53937   0.70   62.8   2757  5.66  5.68  3.56
# 53938   0.86   61.0   2757  6.15  6.12  3.74
# 53939   0.75   62.2   2757  5.83  5.87  3.64
#
# [53794 rows x 6 columns]

# %%
x_catagorical
# Out:
#              cut color clarity
# 0          Ideal     E     SI2
# 1        Premium     E     SI1
# 2           Good     E     VS1
# 3        Premium     I     VS2
# 4           Good     J     SI2
# ...          ...   ...     ...
# 53935      Ideal     D     SI1
# 53936       Good     D     SI1
# 53937  Very Good     D     SI1
# 53938    Premium     H     SI2
# 53939      Ideal     D     SI2
#
# [53794 rows x 3 columns]

# %%
x_contineous_train,x_contineous_test,x_catagorical_train,x_catagorical_test,y_train,y_test =train_test_split(x_contineous,x_catagorical,y,test_size=0.2,random_state=20)

# %%
x_contineous_train.shape,x_contineous_test.shape,x_catagorical_train.shape,x_catagorical_test.shape,len(y_train),len(y_test)
# Out:
# ((43035, 6), (10759, 6), (43035, 3), (10759, 3), 43035, 10759)

# %%
x_contineous_train
# Out:
#        carat  depth  price     x     y     z
# 15385   0.29   61.6    607  4.24  4.27  2.62
# 4417    1.01   63.9   3611  6.37  6.31  4.05
# 16249   1.02   61.4   6499  6.48  6.51  3.99
# 21957   1.12   62.4  10028  6.58  6.66  4.13
# 27242   2.07   62.2  17614  8.16  8.21  5.09
# ...      ...    ...    ...   ...   ...   ...
# 23505   1.51   59.1  11512  7.48  7.52  4.43
# 23829   2.01   62.0  11903  7.88  7.82  4.87
# 37243   0.43   61.7    976  4.84  4.88  2.99
# 27163   2.64   62.3  17407  8.88  8.83  5.52
# 48625   0.70   64.4   2000  5.48  5.52  3.54
#
# [43035 rows x 6 columns]

# %%
x_contineous_test
# Out:
#        carat  depth  price     x     y     z
# 42874   0.45   61.7   1358  4.96  4.93  3.05
# 7746    0.91   63.9   4279  6.10  6.17  3.92
# 18410   1.50   63.2   7484  7.26  7.21  4.57
# 52162   0.55   61.5   2473  5.28  5.26  3.24
# 24613   1.81   62.7  12939  7.77  7.68  4.84
# ...      ...    ...    ...   ...   ...   ...
# 17808   1.04   63.8   7177  6.43  6.40  4.09
# 41066   0.52   62.1   1191  5.14  5.17  3.20
# 11080   0.93   62.7   4925  6.21  6.27  3.91
# 44810   0.50   61.0   1624  5.09  5.14  3.12
# 22967   1.59   61.2  11018  7.50  7.52  4.60
#
# [10759 rows x 6 columns]

# %%
beforenormaltrain=x_contineous_train.copy()
beforenormaltest=x_contineous_test.copy()

# %% [markdown]
# # MinMaxScaler

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
normalscaler=MinMaxScaler()

# %% [markdown]
# # fit_transform

# %%
normalscaler.fit_transform(x_contineous_train)
# Out:
# array([[0.01871102, 0.51666667, 0.01519576, 0.39478585, 0.07249576,
#         0.08238994],
#        [0.16839917, 0.58055556, 0.17764439, 0.59310987, 0.10713073,
#         0.12735849],
#        [0.17047817, 0.51111111, 0.33382003, 0.60335196, 0.11052632,
#         0.1254717 ],
#        ...,
#        [0.04781705, 0.51944444, 0.03515034, 0.45065177, 0.08285229,
#         0.09402516],
#        [0.50727651, 0.53611111, 0.92369673, 0.82681564, 0.14991511,
#         0.17358491],
#        [0.1039501 , 0.59444444, 0.09052563, 0.51024209, 0.09371817,
#         0.11132075]])

# %% [markdown]
# # after fit_transform the out put is numpy array...let's convert in to data frame

# %%
x_contineous_normal_train=pd.DataFrame(normalscaler.fit_transform(x_contineous_train),
                                      columns=x_contineous_train.columns,
                                      index=x_contineous_train.index)

# %%
x_contineous_normal_train
# Out:
#           carat     depth     price         x         y         z
# 15385  0.018711  0.516667  0.015196  0.394786  0.072496  0.082390
# 4417   0.168399  0.580556  0.177644  0.593110  0.107131  0.127358
# 16249  0.170478  0.511111  0.333820  0.603352  0.110526  0.125472
# 21957  0.191268  0.538889  0.524659  0.612663  0.113073  0.129874
# 27242  0.388773  0.533333  0.934891  0.759777  0.139389  0.160063
# ...         ...       ...       ...       ...       ...       ...
# 23505  0.272349  0.447222  0.604910  0.696462  0.127674  0.139308
# 23829  0.376299  0.527778  0.626055  0.733706  0.132767  0.153145
# 37243  0.047817  0.519444  0.035150  0.450652  0.082852  0.094025
# 27163  0.507277  0.536111  0.923697  0.826816  0.149915  0.173585
# 48625  0.103950  0.594444  0.090526  0.510242  0.093718  0.111321
#
# [43035 rows x 6 columns]

# %%
x_contineous_normal_test=pd.DataFrame(normalscaler.fit_transform(x_contineous_test),
                                     columns=x_contineous_test.columns,
                                     index=x_contineous_test.index)

# %%
x_contineous_normal_test
# Out:
#           carat     depth     price         x         y         z
# 42874  0.063613  0.419512  0.055793  0.194268  0.195827  0.474339
# 7746   0.180662  0.526829  0.213710  0.375796  0.394864  0.609642
# 18410  0.330789  0.492683  0.386982  0.560510  0.561798  0.710731
# 52162  0.089059  0.409756  0.116073  0.245223  0.248796  0.503888
# 24613  0.409669  0.468293  0.681894  0.641720  0.637239  0.752722
# ...         ...       ...       ...       ...       ...       ...
# 17808  0.213740  0.521951  0.370384  0.428344  0.431782  0.636081
# 41066  0.081425  0.439024  0.046764  0.222930  0.234350  0.497667
# 11080  0.185751  0.468293  0.248635  0.393312  0.410915  0.608087
# 44810  0.076336  0.385366  0.070174  0.214968  0.229535  0.485226
# 22967  0.353690  0.395122  0.578040  0.598726  0.611557  0.715397
#
# [10759 rows x 6 columns]

# %%
sns.histplot(beforenormaltrain,kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
sns.histplot(x_contineous_normal_train,kde=True)
# Out:
# <Axes: ylabel='Count'>
